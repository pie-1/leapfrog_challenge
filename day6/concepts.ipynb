# %% [markdown]
# Concept,Simple Explanation (English + Nepali)
# Zustand,"Lightweight state management library. Easier and cleaner than Context API or Redux.
# Nepali: सानो र छिटो state management tool।"
# Full CRUD Operations,"Create, Read, Update, Delete — Basic operations every real app needs.
# Nepali: डाटा बनाउने, देखाउने, सम्पादन गर्ने र मेटाउने।"
# Drag & Drop (@dnd-kit),"Allows users to drag tasks between columns.
# Nepali: Task लाई एक column बाट अर्को column मा तान्ने सुविधा।"
# Backend Integration,"Connecting React frontend with Express + MongoDB backend using Axios.
# Nepali: Frontend लाई Backend सँग जोड्ने।"
# Responsive Design,"Works on mobile, tablet and desktop.
# Nepali: सबै Device मा राम्रो देखिने।"
# Event Handling (e.stopPropagation()),"Prevents click event from triggering drag when clicking buttons.
# Nepali: Button click गर्दा drag नहोस् भनेर रोक्ने।"
# useEffect,"Runs code when component loads (fetching tasks on start).
# Nepali: Component load हुँदा data ल्याउने।"
# Async/Await,"Handling API calls properly without blocking UI.
# Nepali: API call लाई सजिलै र सुरक्षित तरिकाले handle गर्ने।"
# Tailwind CSS + Glassmorphism,"Modern, beautiful and artistic UI design.
# Nepali: सुन्दर र आधुनिक design।"
# Separation of Concerns,"Code is properly divided (Store, Components, Routes).
# Nepali: Code लाई सफा र व्यवस्थित राख्ने तरिका।"
